# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
recent_grads=pd.read_csv('recent-grads.csv')
header=recent_grads.iloc[0]
print('shape of the dataset is: ', recent_grads.shape)
recent_grads.head(3)
# Out:
# shape of the dataset is:  (173, 21)
#    Rank  Major_code                           Major   Total     Men  Women  \
# 0     1        2419           PETROLEUM ENGINEERING  2339.0  2057.0  282.0
# 1     2        2416  MINING AND MINERAL ENGINEERING   756.0   679.0   77.0
# 2     3        2415       METALLURGICAL ENGINEERING   856.0   725.0  131.0
#
#   Major_category  ShareWomen  Sample_size  Employed      ...        Part_time  \
# 0    Engineering    0.120564           36      1976      ...              270
# 1    Engineering    0.101852            7       640      ...              170
# 2    Engineering    0.153037            3       648      ...              133
#
#    Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th   P75th  \
# 0                  1207          37           0.018381  110000  95000  125000
# 1                   388          85           0.117241   75000  55000   90000
# 2                   340          16           0.024096   73000  50000  105000
# ...

# %% [markdown]
# ## dropping rows with missing values, and exploring the data using scatter plots

# %%
raw_data_count=recent_grads.shape[0]
recent_grads=recent_grads.dropna()
cleaned_data_count=recent_grads.shape[0]
print(raw_data_count)
print(cleaned_data_count)
# Out:
# 173
# 172

# %%
recent_grads.plot(x='Sample_size',y='Median',kind='Scatter')

# %%
recent_grads.plot(x='Full_time',y='Median',kind='Scatter')

# %%
recent_grads.plot(x='Men',y='Median',kind='Scatter')

# %%
recent_grads.plot(x='Women',y='Median',kind='Scatter')

# %% [markdown]
# ## Histogram plots of the data feastures

# %%
recent_grads['Median'].hist()

# %%
recent_grads['Unemployment_rate'].hist()

# %% [markdown]
# ## Plotting scatter_matrix

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size','Median']],figsize=(7,7))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f438f558be0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f438f45b8d0>]], dtype=object)

# %%
recent_grads[:10].plot.bar(x='Major',y='ShareWomen')
